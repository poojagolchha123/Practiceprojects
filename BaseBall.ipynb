# %% [markdown]
# # Import The Data Set

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('Baseball.csv')
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# # Data Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# # Checking the the null values

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [raw]
# Since there is no null value then we can proceed

# %% [markdown]
# # Checking the types of the columns

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# # DataFrame Description

# %%
df['target']=df['W']

# %%
df.drop(['W'],axis=1,inplace=True)

# %%
df.rename({'target':'W'},axis=1,inplace=True)
df.head()
# Out:
#      R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  SV  \
# 0  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8  56
# 1  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12  45
# 2  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10  38
# 3  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9  37
# 4  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12  35
#
#      E   W
# 0   88  95
# 1   86  83
# 2   79  81
# 3  101  76
# 4   86  74

# %% [markdown]
# # Data Visualization

# %%
sns.scatterplot(x='R',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %%
df.columns
# Out:
# Index(['R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER', 'ERA',
#        'CG', 'SHO', 'SV', 'E', 'W'],
#       dtype='object')

# %%
sns.scatterplot(x='AB',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='W'>

# %%
sns.scatterplot(x='H',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='H', ylabel='W'>

# %%
sns.scatterplot(x='2B',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='W'>

# %%
sns.scatterplot(x='3B',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='W'>

# %%
sns.scatterplot(x='HR',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='W'>

# %%
sns.scatterplot(x='BB',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='W'>

# %%
sns.scatterplot(x='SO',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='W'>

# %%
sns.scatterplot(x='SB',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SB', ylabel='W'>

# %%
sns.scatterplot(x='RA',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='W'>

# %%
sns.scatterplot(x='ER',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='W'>

# %%
sns.scatterplot(x='ERA',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='W'>

# %%
sns.scatterplot(x='CG',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='W'>

# %%
sns.scatterplot(x='SHO',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='W'>

# %%
sns.scatterplot(x='SV',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='W'>

# %%
sns.scatterplot(x='E',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='E', ylabel='W'>

# %%
sns.pairplot(df)

# %% [markdown]
# # BOXPLOT

# %%
df.plot(kind='box',subplots=True,layout=(3,7),figsize=(10,12))
# Out:
# R         AxesSubplot(0.125,0.657941;0.0945122x0.222059)
# AB     AxesSubplot(0.238415,0.657941;0.0945122x0.222059)
# H      AxesSubplot(0.351829,0.657941;0.0945122x0.222059)
# 2B     AxesSubplot(0.465244,0.657941;0.0945122x0.222059)
# 3B     AxesSubplot(0.578659,0.657941;0.0945122x0.222059)
# HR     AxesSubplot(0.692073,0.657941;0.0945122x0.222059)
# BB     AxesSubplot(0.805488,0.657941;0.0945122x0.222059)
# SO        AxesSubplot(0.125,0.391471;0.0945122x0.222059)
# SB     AxesSubplot(0.238415,0.391471;0.0945122x0.222059)
# RA     AxesSubplot(0.351829,0.391471;0.0945122x0.222059)
# ER     AxesSubplot(0.465244,0.391471;0.0945122x0.222059)
# ERA    AxesSubplot(0.578659,0.391471;0.0945122x0.222059)
# CG     AxesSubplot(0.692073,0.391471;0.0945122x0.222059)
# SHO    AxesSubplot(0.805488,0.391471;0.0945122x0.222059)
# SV           AxesSubplot(0.125,0.125;0.0945122x0.222059)
# E         AxesSubplot(0.238415,0.125;0.0945122x0.222059)
# ...

# %% [raw]
# In box plot we have seen that some outliers are presnt in columns E,SHO,ERA,R

# %% [markdown]
# # Normal Distribution Curve

# %%
sns.distplot(df['R'])
# Out:
# C:\Users\pooja\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %%
sns.distplot(df['AB'])
# Out:
# C:\Users\pooja\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='AB', ylabel='Density'>

# %%
sns.distplot(df['H'])
# Out:
# C:\Users\pooja\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='H', ylabel='Density'>

# %%
sns.distplot(df['2B'])
# Out:
# C:\Users\pooja\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='2B', ylabel='Density'>

# %%
sns.distplot(df['3B'])
# Out:
# C:\Users\pooja\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='3B', ylabel='Density'>

# %%
sns.distplot(df['HR'])
# Out:
# C:\Users\pooja\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='HR', ylabel='Density'>

# %%
sns.distplot(df['BB'])
# Out:
# C:\Users\pooja\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='BB', ylabel='Density'>

# %%
sns.distplot(df['SO'])
# Out:
# C:\Users\pooja\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SO', ylabel='Density'>

# %%
sns.distplot(df['SB'])
# Out:
# C:\Users\pooja\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SB', ylabel='Density'>

# %%
sns.distplot(df['RA'])
# Out:
# C:\Users\pooja\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='RA', ylabel='Density'>

# %%
sns.distplot(df['ER'])
# Out:
# C:\Users\pooja\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ER', ylabel='Density'>

# %%
sns.distplot(df['ERA'])
# Out:
# C:\Users\pooja\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ERA', ylabel='Density'>

# %%
sns.distplot(df['CG'])
# Out:
# C:\Users\pooja\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CG', ylabel='Density'>

# %%
sns.distplot(df['SHO'])
# Out:
# C:\Users\pooja\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SHO', ylabel='Density'>

# %%
sns.distplot(df['SV'])
# Out:
# C:\Users\pooja\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SV', ylabel='Density'>

# %%
sns.distplot(df['E'])
# Out:
# C:\Users\pooja\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='E', ylabel='Density'>

# %%
sns.distplot(df['W'])
# Out:
# C:\Users\pooja\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %% [markdown]
# # Describe the Data

# %%
df.describe()
# Out:
#                 R           AB            H          2B         3B  \
# count   30.000000    30.000000    30.000000   30.000000  30.000000
# mean   688.233333  5516.266667  1403.533333  274.733333  31.300000
# std     58.761754    70.467372    57.140923   18.095405  10.452355
# min    573.000000  5385.000000  1324.000000  236.000000  13.000000
# 25%    651.250000  5464.000000  1363.000000  262.250000  23.000000
# 50%    689.000000  5510.000000  1382.500000  275.500000  31.000000
# 75%    718.250000  5570.000000  1451.500000  288.750000  39.000000
# max    891.000000  5649.000000  1515.000000  308.000000  49.000000
#
#                HR          BB          SO          SB          RA          ER  \
# count   30.000000   30.000000    30.00000   30.000000   30.000000   30.000000
# mean   163.633333  469.100000  1248.20000   83.500000  688.233333  635.833333
# std     31.823309   57.053725   103.75947   22.815225   72.108005   70.140786
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt='f')
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variables Summary")
plt.show()

# %% [markdown]
# # Correlation of Data

# %%
df.corr()
# Out:
#             R        AB         H        2B        3B        HR        BB  \
# R    1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283  0.402452
# AB   0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983 -0.136414
# H    0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855 -0.118281
# 2B   0.560084  0.453370  0.566847  1.000000  0.220490  0.056292  0.302700
# 3B  -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915 -0.454949
# HR   0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000  0.425691
# BB   0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691  1.000000
# SO  -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923  0.233652
# SB   0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567 -0.098347
# RA  -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903 -0.416445
# ER  -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922 -0.452663
# ERA -0.049281  0.255551  0.231172 -0.254854  0.330951 -0.090917 -0.459832
# ...

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,linewidth=0.5,linecolor="black",fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [raw]
# # From correlation data we have seen that RA,ER,ERA are negative corelated with W
# And R,2B,BB,SV are positive correlated

# %% [markdown]
# # VIF to find multicolinearity

# %%
v= df.drop('W', axis=1)
v.head(2)
# Out:
#      R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  SV  \
# 0  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8  56
# 1  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12  45
#
#     E
# 0  88
# 1  86

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
scaled= sc.fit_transform(v)
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
VIF= pd.DataFrame()
VIF['features']=v.columns

# %%
VIF['vif']= [variance_inflation_factor(scaled,i) for i in range(len(v.columns))]
VIF
# Out:
#    features          vif
# 0         R    11.522370
# 1        AB    13.311532
# 2         H    10.070668
# 3        2B     4.019297
# 4        3B     3.294146
# 5        HR    10.079902
# 6        BB     3.806098
# 7        SO     2.652401
# 8        SB     2.102684
# 9        RA   191.839155
# 10       ER  1680.387145
# 11      ERA  1222.722240
# 12       CG     3.059904
# 13      SHO     3.654331
# 14       SV     5.798850
# 15        E     2.186219

# %%
v= df.drop(['W','ER'], axis=1)
v.head(2)
# Out:
#      R    AB     H   2B  3B   HR   BB    SO   SB   RA   ERA  CG  SHO  SV   E
# 0  724  5575  1497  300  42  139  383   973  104  641  3.73   2    8  56  88
# 1  696  5467  1349  277  44  156  439  1264   70  700  4.07   2   12  45  86

# %%
scaled=sc.fit_transform(v)
VIF2= pd.DataFrame()
VIF2['features']=v.columns

VIF2['vif']= [variance_inflation_factor(scaled,i) for i in range(len(v.columns))]

VIF2
# Out:
#    features         vif
# 0         R   11.158733
# 1        AB    5.863764
# 2         H    9.628749
# 3        2B    3.786446
# 4        3B    3.293109
# 5        HR    9.057309
# 6        BB    3.791451
# 7        SO    2.607389
# 8        SB    1.849280
# 9        RA  122.133235
# 10      ERA  119.328698
# 11       CG    2.741188
# 12      SHO    3.410561
# 13       SV    3.203815
# 14        E    2.107345

# %%
v= df.drop(['W','ER','RA'], axis=1)
scaled=sc.fit_transform(v)
VIF3= pd.DataFrame()
VIF3['features']=v.columns

VIF3['vif']= [variance_inflation_factor(scaled,i) for i in range(len(v.columns))]

VIF3
# Out:
#    features        vif
# 0         R  10.987898
# 1        AB   4.399954
# 2         H   8.941874
# 3        2B   3.729413
# 4        3B   3.142717
# 5        HR   7.882841
# 6        BB   3.468244
# 7        SO   2.155496
# 8        SB   1.819823
# 9       ERA   4.951981
# 10       CG   2.723370
# 11      SHO   3.227759
# 12       SV   2.948133
# 13        E   2.040676

# %%
v.head(3)
# Out:
#      R    AB     H   2B  3B   HR   BB    SO   SB   ERA  CG  SHO  SV   E
# 0  724  5575  1497  300  42  139  383   973  104  3.73   2    8  56  88
# 1  696  5467  1349  277  44  156  439  1264   70  4.07   2   12  45  86
# 2  669  5439  1395  303  29  141  533  1157   86  3.67  11   10  38  79

# %% [markdown]
# # Skewness of the data

# %%
v.skew()
# Out:
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# # Removing The Outliers

# %%
for i in v.columns:
    sns.boxplot(v[i])
    plt.show()
# Out:
# C:\Users\pooja\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\pooja\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\pooja\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
v.columns
# Out:
# Index(['R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO',
#        'SV', 'E'],
#       dtype='object')

# %%
IQR= df['R'].quantile(.75)-df['R'].quantile(.25)
IQR
upper= df['R'].quantile(.75) +( 1.5 * IQR)
upper
# Out:
# 818.75

# %%
v['R']= np.where(v['R']>upper,upper,v['R'])

# %%
IQR= df['ERA'].quantile(.75)-df['ERA'].quantile(.25)
IQR
upper= df['ERA'].quantile(.75) +( 1.5 * IQR)
upper
v['ERA']= np.where(v['ERA']>upper,upper,v['ERA'])

# %%
IQR= df['SHO'].quantile(.75)-df['SHO'].quantile(.25)
IQR
upper= df['SHO'].quantile(.75) +( 1.5 * IQR)
upper
v['SHO']= np.where(v['SHO']>upper,upper,v['SHO'])

# %%
IQR= df['SV'].quantile(.75)-df['SV'].quantile(.25)
IQR
upper= df['SV'].quantile(.75) +( 1.5 * IQR)
upper
v['SV']= np.where(v['SV']>upper,upper,v['SV'])

# %%
IQR= df['E'].quantile(.75)-df['E'].quantile(.25)
IQR
upper= df['E'].quantile(.75) +( 1.5 * IQR)
upper
v['E']= np.where(v['E']>upper,upper,v['E'])

# %%
for i in v.columns:
    sns.boxplot(v[i])
    plt.show()
# Out:
# C:\Users\pooja\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\pooja\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\pooja\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
v.skew()
# Out:
# R      0.284282
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# ERA    0.037969
# CG     0.736845
# SHO    0.218030
# SV     0.612333
# E      0.504019
# dtype: float64

# %% [markdown]
# # Tranformation

# %%
from sklearn.preprocessing import power_transform
transformed=power_transform(v)
transformed=pd.DataFrame(transformed)
transformed.columns=v.columns
transformed=pd.DataFrame(transformed)
transformed.columns=v.columns
transformed.skew()
# Out:
# C:\Users\pooja\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# R      0.000000
# AB     0.000000
# H      0.000000
# 2B    -0.035315
# 3B    -0.072933
# HR    -0.000065
# BB    -0.007760
# SO     0.041170
# SB    -0.010455
# ERA    0.001204
# CG    -0.059785
# SHO   -0.017889
# SV     0.001270
# E      0.032939
# dtype: float64

# %%
transformed.head(2)
# Out:
#      R   AB    H        2B        3B        HR        BB        SO        SB  \
# 0  0.0  0.0  0.0  1.477685  1.033103 -0.764626 -1.610915 -2.569896  0.939708
# 1  0.0  0.0  0.0  0.084269  1.203320 -0.158581 -0.502749  0.134913 -0.539693
#
#         ERA        CG       SHO        SV         E
# 0 -0.502797 -0.359844 -0.827928  1.564693 -0.357505
# 1  0.261440 -0.359844  0.258244  0.361185 -0.560947

# %% [markdown]
# # Standardization

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaled=sc.fit_transform(transformed)

# %% [markdown]
# # Separting The data Into X and Y

# %%
x=scaled
x.shape
# Out:
# (30, 14)

# %%
y=df['W']
y.shape
# Out:
# (30,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
lr=LinearRegression()
from sklearn.metrics import r2_score

# %% [markdown]
# # Checking Random State Value

# %%
for i in range(0,200):
    xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(xtrain,ytrain)
    predtrain=lr.predict(xtrain)
    predtest=lr.predict(xtest)
    print(f"at random state{i},the training accuracy is : {r2_score(ytrain,predtrain)}")
    print(f"at random state{i},the testing accuracy is : {r2_score(ytest,predtest)}")
    print("\n")
# Out:
# at random state0,the training accuracy is : 0.8868750141483405
# at random state0,the testing accuracy is : 0.4731727128343427
#
#
# at random state1,the training accuracy is : 0.9275243758794135
# at random state1,the testing accuracy is : 0.4066894663073667
#
#
# at random state2,the training accuracy is : 0.9258970043835755
# at random state2,the testing accuracy is : -0.4338975661041229
#
#
# at random state3,the training accuracy is : 0.9040355998774858
# at random state3,the testing accuracy is : 0.36925174760933355
#
#
# at random state4,the training accuracy is : 0.8376796424729671
# at random state4,the testing accuracy is : 0.8993524503970529
#
#
# at random state5,the training accuracy is : 0.8698399244524176
# at random state5,the testing accuracy is : 0.5953543423282144
#
#
# at random state6,the training accuracy is : 0.8724849886350237
# at random state6,the testing accuracy is : 0.6997255120692769
#
#
# at random state7,the training accuracy is : 0.8884015019604656
# ...

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=175)
lr.fit(xtrain,ytrain)
predtrain=lr.predict(xtrain)
predtest=lr.predict(xtest)
print(f"at random state{i},the training accuracy is : {r2_score(ytrain,predtrain)}")
print(f"at random state{i},the testing accuracy is : {r2_score(ytest,predtest)}")
print("\n")
print(lr.coef_)
print(lr.intercept_)
print('error')
print("mean absolute error",mean_absolute_error(ytest,predtest))
print("mean Squared error",mean_squared_error(ytest,predtest))
print('Root mean squared error',np.sqrt(mean_squared_error(ytest,predtest)))
# Out:
# at random state199,the training accuracy is : 0.8588439063233215
# at random state199,the testing accuracy is : 0.8625266724208733
#
#
# [ 0.00000000e+00  6.66133815e-16 -1.33226763e-15  5.78526063e-01
#   1.12955934e+00  3.79025207e+00  2.04750285e-01 -1.95346555e+00
#  -2.08634478e-01 -6.53617196e+00  1.25791194e+00  3.07124637e-01
#   4.17959026e+00  1.12601296e+00]
# 81.08926255893694
# error
# mean absolute error 2.7264065961746673
# mean Squared error 13.319637960999827
# Root mean squared error 3.649607918804406

# %% [markdown]
# # Cross valiation Of the Model

# %%
Training_accuracy=r2_score(ytrain,predtrain)
Testing_accuracy=r2_score(ytest,predtest)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f"ar cross fold {j} the cv score is{cv_mean} and accuarcy score for training is {Training_accuracy} and accuracy for testing is{Testing_accuracy}")
    print('\n')
# Out:
# ar cross fold 2 the cv score is-1.5663586503045905 and accuarcy score for training is 0.8588439063233215 and accuracy for testing is0.8625266724208733
#
#
# ar cross fold 3 the cv score is0.29508162751233774 and accuarcy score for training is 0.8588439063233215 and accuracy for testing is0.8625266724208733
#
#
# ar cross fold 4 the cv score is0.5724314897777351 and accuarcy score for training is 0.8588439063233215 and accuracy for testing is0.8625266724208733
#
#
# ar cross fold 5 the cv score is0.06633907636189244 and accuarcy score for training is 0.8588439063233215 and accuracy for testing is0.8625266724208733
#
#
# ar cross fold 6 the cv score is0.05527775720870263 and accuarcy score for training is 0.8588439063233215 and accuracy for testing is0.8625266724208733
#
#
# ar cross fold 7 the cv score is0.05329482433706253 and accuarcy score for training is 0.8588439063233215 and accuracy for testing is0.8625266724208733
#
#
# ...

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=ytest,y=predtest,color='r')
plt.plot(ytest,ytest,color='b')
plt.xlabel('Actual Win',fontsize=14)
plt.ylabel("Predicted Win",fontsize=14)
plt.title("Linear Regression",fontsize=18)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
LR_model= LinearRegression()
RD_model= Ridge()
LS_model= Lasso()
DT_model= DecisionTreeRegressor()
SV_model= SVR()
KNR_model= KNeighborsRegressor()
RFR_model= RandomForestRegressor()
Elastic_model= ElasticNet()
SGH_model= SGDRegressor()
Bag_model=BaggingRegressor()
ADA_model=AdaBoostRegressor()
GB_model= GradientBoostingRegressor()

model=[LR_model,RD_model,LS_model,DT_model,SV_model,KNR_model,RFR_model,Elastic_model,SGH_model,Bag_model,ADA_model,GB_model ]

# %%
for m in model:
    m.fit(xtrain,ytrain)
    print('mean_absolute_error of ',m ,'model', mean_absolute_error(ytest,m.predict(xtest)))
    print('mean_square_error of',m,'model' , mean_squared_error(ytest,m.predict(xtest)))
    print('R2 Score of',m,'model', r2_score(ytest,m.predict(xtest) )*100)
    print('X' * 50, '\n\n')
# Out:
# mean_absolute_error of  LinearRegression() model 2.7264065961746673
# mean_square_error of LinearRegression() model 13.319637960999827
# R2 Score of LinearRegression() model 86.25266724208733
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
#
# mean_absolute_error of  Ridge() model 2.294706185531917
# mean_square_error of Ridge() model 11.152294329870855
# R2 Score of Ridge() model 88.48960447605072
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
#
# mean_absolute_error of  Lasso() model 2.851798496410254
# mean_square_error of Lasso() model 9.180635618736224
# R2 Score of Lasso() model 90.524573329286
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
#
# mean_absolute_error of  DecisionTreeRegressor() model 9.333333333333334
# mean_square_error of DecisionTreeRegressor() model 106.0
# R2 Score of DecisionTreeRegressor() model -9.403669724770625
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
#
# mean_absolute_error of  SVR() model 8.005345608904014
# ...

# %% [markdown]
# # CROSS Validation

# %%
from sklearn.model_selection import cross_val_score
for i in model:
    print('mean_square of ',i, 'model',mean_squared_error(ytest,i.predict(xtest)))
    print("cross Validation score of ",i ," is ",cross_val_score(i,x,y,cv=10, scoring='neg_mean_squared_error').mean())
    print('*'*50)
# Out:
# mean_square of  LinearRegression() model 13.319637960999827
# cross Validation score of  LinearRegression()  is  -55.10832658669832
# **************************************************
# mean_square of  Ridge() model 11.152294329870855
# cross Validation score of  Ridge()  is  -47.703110230419824
# **************************************************
# mean_square of  Lasso() model 9.180635618736224
# cross Validation score of  Lasso()  is  -38.00120143901657
# **************************************************
# mean_square of  DecisionTreeRegressor() model 106.0
# cross Validation score of  DecisionTreeRegressor()  is  -108.46666666666667
# **************************************************
# mean_square of  SVR() model 91.1232721063577
# cross Validation score of  SVR()  is  -101.43654219683
# **************************************************
# mean_square of  KNeighborsRegressor() model 55.53999999999997
# cross Validation score of  KNeighborsRegressor()  is  -80.90266666666668
# ...

# %%
for i in model:
    print('Root mean_square of ',i, 'model',np.sqrt(mean_squared_error(ytest,i.predict(xtest))))
    score=cross_val_score(i,x,y,cv=10, scoring='neg_mean_squared_error').mean()
    print("cross Validation score of root mean square ",i ," is ",np.sqrt(-score))
    print('*'*50)
# Out:
# Root mean_square of  LinearRegression() model 3.649607918804406
# cross Validation score of root mean square  LinearRegression()  is  7.42349827148214
# **************************************************
# Root mean_square of  Ridge() model 3.3395051025370295
# cross Validation score of root mean square  Ridge()  is  6.906743822556315
# **************************************************
# Root mean_square of  Lasso() model 3.029956372414663
# cross Validation score of root mean square  Lasso()  is  6.164511451771062
# **************************************************
# Root mean_square of  DecisionTreeRegressor() model 10.295630140987
# cross Validation score of root mean square  DecisionTreeRegressor()  is  10.538817137927134
# **************************************************
# Root mean_square of  SVR() model 9.545851041492199
# cross Validation score of root mean square  SVR()  is  10.071570989514496
# **************************************************
# ...

# %% [markdown]
# # Saving model in pickle format

# %%
import joblib
joblib.dump(LS_model,"Baseball.pkl")
# Out:
# ['Baseball.pkl']
